# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv(r"C:\Users\ASUS\Downloads\zomato.csv")
data
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
data.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          51717 non-null  object
#  1   address                      51717 non-null  object
#  2   name                         51717 non-null  object
#  3   online_order                 51717 non-null  object
#  4   book_table                   51717 non-null  object
#  5   rate                         43942 non-null  object
#  6   votes                        51717 non-null  int64
#  7   phone                        50509 non-null  object
#  8   location                     51696 non-null  object
#  9   rest_type                    51490 non-null  object
#  10  dish_liked                   23639 non-null  object
#  11  cuisines                     51672 non-null  object
#  12  approx_cost(for two people)  51371 non-null  object
# ...

# %%
data.isnull().sum()
# Out:
# url                                0
# address                            0
# name                               0
# online_order                       0
# book_table                         0
# rate                            7775
# votes                              0
# phone                           1208
# location                          21
# rest_type                        227
# dish_liked                     28078
# cuisines                          45
# approx_cost(for two people)      346
# reviews_list                       0
# menu_item                          0
# listed_in(type)                    0
# listed_in(city)                    0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.drop(columns = ['url','address','phone'],inplace = True)

# %%
data
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table    rate  votes                    location  \
# 0            Yes   4.1/5    775                Banashankari
# ...

# %% [markdown]
# # Univariate analysis

# %%
len(data['name'].unique())
# Out:
# 8792

# %%
data['online_order'].value_counts()
# Out:
# Yes    30444
# No     21273
# Name: online_order, dtype: int64

# %%
x = data['online_order'].value_counts()
y = x.index
plt.pie(x=x, labels = y, colors = ['lightcoral','lightskyblue'],autopct = '%.2f%%',explode = (0,0.1), shadow = True)
plt.title('Online order Percentage',color = 'black')
# Out:
# Text(0.5, 1.0, 'Online order Percentage')

# %%
x = data['book_table'].value_counts()
y = x.index
plt.pie(x=x, labels = y, colors = ['coral','skyblue'],autopct = '%.2f%%',explode = (0,0.1), shadow = True)
plt.title('Table Booking Ratio',color = 'black')
# Out:
# Text(0.5, 1.0, 'Table Booking Ratio')

# %%
data.rate.isnull().sum()
# Out:
# 7775

# %%
threshold = len(data)*0.05
threshold
# Out:
# 2585.8500000000004

# %%
len(data)
# Out:
# 51717

# %%
cols_to_drop = data.columns[data.isna().sum() <= threshold]
cols_to_drop
# Out:
# Index(['name', 'online_order', 'book_table', 'votes', 'location', 'rest_type',
#        'cuisines', 'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
data.dropna(subset = cols_to_drop, inplace = True)

# %%
data.shape
# Out:
# (51148, 14)

# %%
data.isna().sum()
# Out:
# name                               0
# online_order                       0
# book_table                         0
# rate                            7615
# votes                              0
# location                           0
# rest_type                          0
# dish_liked                     27713
# cuisines                           0
# approx_cost(for two people)        0
# reviews_list                       0
# menu_item                          0
# listed_in(type)                    0
# listed_in(city)                    0
# dtype: int64

# %%
data.dish_liked
# Out:
# 0        Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1        Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2        Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                              Masala Dosa
# 4                                      Panipuri, Gol Gappe
#                                ...
# 51712                                                  NaN
# 51713                                                  NaN
# 51714                                                  NaN
# 51715                         Cocktails, Pizza, Buttermilk
# 51716                                                  NaN
# Name: dish_liked, Length: 51148, dtype: object

# %%
data.dish_liked.unique()
# Out:
# array(['Pasta, Lunch Buffet, Masala Papad, Paneer Lajawab, Tomato Shorba, Dum Biryani, Sweet Corn Soup',
#        'Momos, Lunch Buffet, Chocolate Nirvana, Thai Green Curry, Paneer Tikka, Dum Biryani, Chicken Biryani',
#        'Churros, Cannelloni, Minestrone Soup, Hot Chocolate, Pink Sauce Pasta, Salsa, Veg Supreme Pizza',
#        ...,
#        'Noodles, Chicken Noodle, Momos, American Chopsuey, Salad, Manchow Soup, Manchurian',
#        'Chicken Quesadilla, Naan, Breakfast Buffet, Cheesecake, Cocktails, Lunch Buffet, Biryani',
#        'Biryani, Andhra Meal'], dtype=object)

# %%
data.dish_liked.mode()
# Out:
# 0    Biryani
# Name: dish_liked, dtype: object

# %%
data['dish_liked'].fillna('Biryani',inplace = True)

# %%
data.isna().sum()
# Out:
# name                              0
# online_order                      0
# book_table                        0
# rate                           7615
# votes                             0
# location                          0
# rest_type                         0
# dish_liked                        0
# cuisines                          0
# approx_cost(for two people)       0
# reviews_list                      0
# menu_item                         0
# listed_in(type)                   0
# listed_in(city)                   0
# dtype: int64

# %%
data.rate.dtype
# Out:
# dtype('O')

# %%
data.rate
# Out:
# 0         4.1/5
# 1         4.1/5
# 2         3.8/5
# 3         3.7/5
# 4         3.8/5
#           ...
# 51712    3.6 /5
# 51713       NaN
# 51714       NaN
# 51715    4.3 /5
# 51716    3.4 /5
# Name: rate, Length: 51148, dtype: object

# %%
data.rate = data.rate.str.replace('/5','')
data.rate = data.rate.str.replace('NEW','')
data.rate = data.rate.str.replace('-','')

# %%
data.rate
# Out:
# 0         4.1
# 1         4.1
# 2         3.8
# 3         3.7
# 4         3.8
#          ...
# 51712    3.6
# 51713     NaN
# 51714     NaN
# 51715    4.3
# 51716    3.4
# Name: rate, Length: 51148, dtype: object

# %%
data.rate.unique()
# Out:
# array(['4.1', '3.8', '3.7', '3.6', '4.6', '4.0', '4.2', '3.9', '3.1',
#        '3.0', '3.2', '3.3', '2.8', '4.4', '4.3', '', '2.9', '3.5', nan,
#        '2.6', '3.8 ', '3.4', '4.5', '2.5', '2.7', '4.7', '2.4', '2.2',
#        '2.3', '3.4 ', '3.6 ', '4.8', '3.9 ', '4.2 ', '4.0 ', '4.1 ',
#        '3.7 ', '3.1 ', '2.9 ', '3.3 ', '2.8 ', '3.5 ', '2.7 ', '2.5 ',
#        '3.2 ', '2.6 ', '4.5 ', '4.3 ', '4.4 ', '4.9', '2.1', '2.0', '1.8',
#        '4.6 ', '4.9 ', '3.0 ', '4.8 ', '2.3 ', '4.7 ', '2.4 ', '2.1 ',
#        '2.2 ', '2.0 ', '1.8 '], dtype=object)

# %%
data.rate = pd.to_numeric(data.rate)
data.rate.dtype
# Out:
# dtype('float64')

# %%
sns.displot(data.rate,kde = True)

# %%
data.rate.fillna(data.rate.mean(),inplace = True)

# %%
data.isnull().sum()
# Out:
# name                           0
# online_order                   0
# book_table                     0
# rate                           0
# votes                          0
# location                       0
# rest_type                      0
# dish_liked                     0
# cuisines                       0
# approx_cost(for two people)    0
# reviews_list                   0
# menu_item                      0
# listed_in(type)                0
# listed_in(city)                0
# dtype: int64

# %%
data.votes.unique()
# Out:
# array([ 775,  787,  918, ..., 4957, 2382,  843], dtype=int64)

# %%
plt.figure(figsize = (10,10))
plt.scatter(y=data.votes,x=data.index)

# %%
data.location.unique()
# Out:
# array(['Banashankari', 'Basavanagudi', 'Mysore Road', 'Jayanagar',
#        'Kumaraswamy Layout', 'Rajarajeshwari Nagar', 'Vijay Nagar',
#        'Uttarahalli', 'JP Nagar', 'South Bangalore', 'City Market',
#        'Nagarbhavi', 'Bannerghatta Road', 'BTM', 'Kanakapura Road',
#        'Bommanahalli', 'CV Raman Nagar', 'Electronic City', 'HSR',
#        'Marathahalli', 'Wilson Garden', 'Shanti Nagar',
#        'Koramangala 5th Block', 'Koramangala 8th Block', 'Richmond Road',
#        'Koramangala 7th Block', 'Jalahalli', 'Koramangala 4th Block',
#        'Bellandur', 'Sarjapur Road', 'Whitefield', 'East Bangalore',
#        'Old Airport Road', 'Indiranagar', 'Koramangala 1st Block',
#        'Frazer Town', 'RT Nagar', 'MG Road', 'Brigade Road',
#        'Lavelle Road', 'Church Street', 'Ulsoor', 'Residency Road',
#        'Shivajinagar', 'Infantry Road', 'St. Marks Road',
#        'Cunningham Road', 'Race Course Road', 'Commercial Street',
# ...

# %%
plt.figure(figsize  = (15,5))
sns.countplot(x = 'location',data = data)
plt.xticks(rotation = 90)
plt.show()

# %%
data.rest_type.unique()
# Out:
# array(['Casual Dining', 'Cafe, Casual Dining', 'Quick Bites',
#        'Casual Dining, Cafe', 'Cafe', 'Quick Bites, Cafe',
#        'Cafe, Quick Bites', 'Delivery', 'Mess', 'Dessert Parlor',
#        'Bakery, Dessert Parlor', 'Pub', 'Bakery', 'Takeaway, Delivery',
#        'Fine Dining', 'Beverage Shop', 'Sweet Shop', 'Bar',
#        'Beverage Shop, Quick Bites', 'Confectionery',
#        'Quick Bites, Beverage Shop', 'Dessert Parlor, Sweet Shop',
#        'Bakery, Quick Bites', 'Sweet Shop, Quick Bites', 'Kiosk',
#        'Food Truck', 'Quick Bites, Dessert Parlor',
#        'Beverage Shop, Dessert Parlor', 'Takeaway', 'Pub, Casual Dining',
#        'Casual Dining, Bar', 'Dessert Parlor, Beverage Shop',
#        'Quick Bites, Bakery', 'Dessert Parlor, Quick Bites',
#        'Microbrewery, Casual Dining', 'Lounge', 'Bar, Casual Dining',
#        'Food Court', 'Cafe, Bakery', 'Dhaba', 'Quick Bites, Sweet Shop',
#        'Microbrewery', 'Food Court, Quick Bites', 'Pub, Bar',
# ...

# %%
plt.figure(figsize  = (15,5))
sns.countplot(x = 'rest_type',data = data)
plt.xticks(rotation = 90)
plt.show()

# %%
data.rename(columns ={'approx_cost(for two people)': 'cost', 'listed_in(type)' : 'service','listed_in(city)':'city'},inplace = True)

# %%
data.columns
# Out:
# Index(['name', 'online_order', 'book_table', 'rate', 'votes', 'location',
#        'rest_type', 'dish_liked', 'cuisines', 'cost', 'reviews_list',
#        'menu_item', 'service', 'city'],
#       dtype='object')

# %%
data.cost.unique()
# Out:
# array(['800', '300', '600', '700', '550', '500', '450', '650', '400',
#        '900', '200', '750', '150', '850', '100', '1,200', '350', '250',
#        '950', '1,000', '1,500', '1,300', '199', '80', '1,100', '160',
#        '1,600', '230', '130', '50', '190', '1,700', '1,400', '180',
#        '1,350', '2,200', '2,000', '1,800', '1,900', '330', '2,500',
#        '2,100', '3,000', '2,800', '3,400', '40', '1,250', '3,500',
#        '4,000', '2,400', '2,600', '120', '1,450', '469', '70', '3,200',
#        '60', '560', '240', '360', '6,000', '1,050', '2,300', '4,100',
#        '5,000', '3,700', '1,650', '2,700', '4,500', '140'], dtype=object)

# %%
data.cost = data.cost.str.replace(',','')

# %%
data.cost = pd.to_numeric(data.cost)

# %%
data.cost.unique()
# Out:
# array([ 800,  300,  600,  700,  550,  500,  450,  650,  400,  900,  200,
#         750,  150,  850,  100, 1200,  350,  250,  950, 1000, 1500, 1300,
#         199,   80, 1100,  160, 1600,  230,  130,   50,  190, 1700, 1400,
#         180, 1350, 2200, 2000, 1800, 1900,  330, 2500, 2100, 3000, 2800,
#        3400,   40, 1250, 3500, 4000, 2400, 2600,  120, 1450,  469,   70,
#        3200,   60,  560,  240,  360, 6000, 1050, 2300, 4100, 5000, 3700,
#        1650, 2700, 4500,  140], dtype=int64)

# %%
plt.figure(figsize=(10,5))
sns.displot(data.cost)
plt.show()

# %%
data
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table      rate  votes                    location  \
# 0            Yes  4.100000    775                Banashankari
# ...

# %% [markdown]
# # Q.1)Restaurants delivering Online or not

# %%
data.head(2)
# Out:
#              name online_order book_table  rate  votes      location  \
# 0           Jalsa          Yes        Yes   4.1    775  Banashankari
# 1  Spice Elephant          Yes         No   4.1    787  Banashankari
#
#        rest_type                                         dish_liked  \
# 0  Casual Dining  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Casual Dining  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
#
#                          cuisines  cost  \
# 0  North Indian, Mughlai, Chinese   800
# 1     Chinese, North Indian, Thai   800
#
#                                         reviews_list menu_item service  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []  Buffet
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []  Buffet
#
#            city
# 0  Banashankari
# 1  Banashankari

# %%
a2 = data['online_order'].value_counts()
b2 = a2.index

# %%
data[data['online_order']=='Yes']
# Out:
#                            name online_order book_table  rate  votes  \
# 0                         Jalsa          Yes        Yes   4.1    775
# 1                Spice Elephant          Yes         No   4.1    787
# 2               San Churro Cafe          Yes         No   3.8    918
# 5               Timepass Dinner          Yes         No   3.8    286
# 7                        Onesta          Yes        Yes   4.6   2556
# ...                         ...          ...        ...   ...    ...
# 51697  Shizusan Shophouse & Bar          Yes        Yes   4.4   1313
# 51699        Harry's Bar + Cafe          Yes        Yes   4.1   1218
# 51701             The Beer Cafe          Yes        Yes   4.1    673
# 51703      Oliver's Pub & Diner          Yes        Yes   3.9    548
# 51705        Izakaya Gastro Pub          Yes        Yes   3.8    128
#
#            location            rest_type  \
# 0      Banashankari        Casual Dining
# 1      Banashankari        Casual Dining
# ...

# %%
data[data['online_order']=='No']
# Out:
#                                                     name online_order  \
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# 6        Rosewood International Hotel - Bar & Restaurant           No
# 13                                            Caf-Eleven           No
# 18                                              T3H Cafe           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table      rate  votes                    location  \
# 3             No  3.700000     88                Banashankari
# ...

# %%
plt.pie(a2,labels = b2,autopct = '%.2f%%')
plt.show()

# %% [markdown]
# # Q.2)Restaurants allowing table booking or not?

# %%
data.head(2)
# Out:
#              name online_order book_table  rate  votes      location  \
# 0           Jalsa          Yes        Yes   4.1    775  Banashankari
# 1  Spice Elephant          Yes         No   4.1    787  Banashankari
#
#        rest_type                                         dish_liked  \
# 0  Casual Dining  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Casual Dining  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
#
#                          cuisines  cost  \
# 0  North Indian, Mughlai, Chinese   800
# 1     Chinese, North Indian, Thai   800
#
#                                         reviews_list menu_item service  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []  Buffet
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []  Buffet
#
#            city
# 0  Banashankari
# 1  Banashankari

# %%
data['book_table'].value_counts()
# Out:
# No     44699
# Yes     6449
# Name: book_table, dtype: int64

# %%
data[data['book_table']=='Yes']
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 7                                                 Onesta          Yes
# 11                                          Cafe Shuffle          Yes
# 12                                      The Coffee Shack          Yes
# 44                                                Onesta          Yes
# ...                                                  ...          ...
# 51701                                      The Beer Cafe          Yes
# 51703                               Oliver's Pub & Diner          Yes
# 51704                                            Smaaash           No
# 51705                                 Izakaya Gastro Pub          Yes
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
#
#       book_table  rate  votes                    location  \
# 0            Yes   4.1    775                Banashankari
# ...

# %%
data[data['book_table']=='No']
# Out:
#                                                     name online_order  \
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# 5                                        Timepass Dinner          Yes
# ...                                                  ...          ...
# 51711                                            Bhagini           No
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table      rate  votes                    location  \
# 1             No  4.100000    787                Banashankari
# ...

# %%
a3 = data['book_table'].value_counts()
b3 = a3.index
plt.pie(a3,labels = b3,autopct = '%.2f%%')
plt.show()

# %% [markdown]
# # Q.3)Table booking Rate vs Rate?

# %%
data.head(2)
# Out:
#              name online_order book_table  rate  votes      location  \
# 0           Jalsa          Yes        Yes   4.1    775  Banashankari
# 1  Spice Elephant          Yes         No   4.1    787  Banashankari
#
#        rest_type                                         dish_liked  \
# 0  Casual Dining  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Casual Dining  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
#
#                          cuisines  cost  \
# 0  North Indian, Mughlai, Chinese   800
# 1     Chinese, North Indian, Thai   800
#
#                                         reviews_list menu_item service  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []  Buffet
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []  Buffet
#
#            city
# 0  Banashankari
# 1  Banashankari

# %%
sns.barplot(x = 'book_table', y = 'rate',data = data)
plt.title('table booking vs rate')
# Out:
# Text(0.5, 1.0, 'table booking vs rate')

# %% [markdown]
# # Q.4)Best Location?

# %%
data.head(2)
# Out:
#              name online_order book_table  rate  votes      location  \
# 0           Jalsa          Yes        Yes   4.1    775  Banashankari
# 1  Spice Elephant          Yes         No   4.1    787  Banashankari
#
#        rest_type                                         dish_liked  \
# 0  Casual Dining  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Casual Dining  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
#
#                          cuisines  cost  \
# 0  North Indian, Mughlai, Chinese   800
# 1     Chinese, North Indian, Thai   800
#
#                                         reviews_list menu_item service  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []  Buffet
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []  Buffet
#
#            city
# 0  Banashankari
# 1  Banashankari

# %%
df = data.groupby('location')['rate','votes'].mean()

# %%
df.sort_values(by = ['rate','votes'],ascending = False)
df = df.head(10)
l = x.index.to_list()
df
# Out:
#                         rate       votes
# location
# BTM                 3.602110  113.204102
# Banashankari        3.659095  179.617257
# Banaswadi           3.552800   54.131783
# Bannerghatta Road   3.555788  133.463066
# Basavanagudi        3.675116  138.770468
# Basaveshwara Nagar  3.664752   95.962567
# Bellandur           3.568176  161.537372
# Bommanahalli        3.390191   32.639831
# Brigade Road        3.704790  352.725780
# Brookefield         3.617267  181.344512

# %%
sns.barplot(x = df.index , y = df.rate, data = df)
plt.xticks(rotation = 90)
plt.title('Best location by rating')
plt.show()

# %% [markdown]
# # Q.5)Relation Between Location and Rating?

# %%
data.head(2)
# Out:
#              name online_order book_table  rate  votes      location  \
# 0           Jalsa          Yes        Yes   4.1    775  Banashankari
# 1  Spice Elephant          Yes         No   4.1    787  Banashankari
#
#        rest_type                                         dish_liked  \
# 0  Casual Dining  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Casual Dining  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
#
#                          cuisines  cost  \
# 0  North Indian, Mughlai, Chinese   800
# 1     Chinese, North Indian, Thai   800
#
#                                         reviews_list menu_item service  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []  Buffet
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []  Buffet
#
#            city
# 0  Banashankari
# 1  Banashankari

# %%
plt.figure(figsize = (20,10))
sns.scatterplot(data['location'], data['rate'])
plt.xlabel('location')
plt.ylabel('rate')
plt.title('Relation Between location and rate')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # Q.6)Restaurant types?

# %%
data.head(2)
# Out:
#              name online_order book_table  rate  votes      location  \
# 0           Jalsa          Yes        Yes   4.1    775  Banashankari
# 1  Spice Elephant          Yes         No   4.1    787  Banashankari
#
#        rest_type                                         dish_liked  \
# 0  Casual Dining  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Casual Dining  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
#
#                          cuisines  cost  \
# 0  North Indian, Mughlai, Chinese   800
# 1     Chinese, North Indian, Thai   800
#
#                                         reviews_list menu_item service  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []  Buffet
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []  Buffet
#
#            city
# 0  Banashankari
# 1  Banashankari

# %%
data['rest_type'].value_counts()
# Out:
# Quick Bites                   19046
# Casual Dining                 10273
# Cafe                           3687
# Delivery                       2578
# Dessert Parlor                 2245
#                               ...
# Dessert Parlor, Kiosk             2
# Food Court, Beverage Shop         2
# Dessert Parlor, Food Court        2
# Quick Bites, Kiosk                1
# Sweet Shop, Dessert Parlor        1
# Name: rest_type, Length: 93, dtype: int64

# %%
plt.figure(figsize = (15,8))
sns.barplot(y = 'rate' , x = 'rest_type',  data = data)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # Q.7)Gaussian Rest type and Rating?

# %%
data.head(2)
# Out:
#              name online_order book_table  rate  votes      location  \
# 0           Jalsa          Yes        Yes   4.1    775  Banashankari
# 1  Spice Elephant          Yes         No   4.1    787  Banashankari
#
#        rest_type                                         dish_liked  \
# 0  Casual Dining  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Casual Dining  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
#
#                          cuisines  cost  \
# 0  North Indian, Mughlai, Chinese   800
# 1     Chinese, North Indian, Thai   800
#
#                                         reviews_list menu_item service  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []  Buffet
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []  Buffet
#
#            city
# 0  Banashankari
# 1  Banashankari

# %%
rest_type_rating = data.groupby('rest_type')['rate'].mean().sort_values(ascending = False)

# %%
data['rate'] = pd.to_numeric(data['rate'] , errors = 'coerce')
data.dropna(subset = ['rate'] , inplace = True)

# %%
plt.figure(figsize=(12, 6))
rest_type_rating.plot(kind='bar', color='skyblue')
plt.title("Average Ratings by Restaurant Type")
plt.xlabel("Restaurant Type")
plt.ylabel("Average Rating")
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
data['rest_type'].unique()
# Out:
# array(['Casual Dining', 'Cafe, Casual Dining', 'Quick Bites',
#        'Casual Dining, Cafe', 'Cafe', 'Quick Bites, Cafe',
#        'Cafe, Quick Bites', 'Delivery', 'Mess', 'Dessert Parlor',
#        'Bakery, Dessert Parlor', 'Pub', 'Bakery', 'Takeaway, Delivery',
#        'Fine Dining', 'Beverage Shop', 'Sweet Shop', 'Bar',
#        'Beverage Shop, Quick Bites', 'Confectionery',
#        'Quick Bites, Beverage Shop', 'Dessert Parlor, Sweet Shop',
#        'Bakery, Quick Bites', 'Sweet Shop, Quick Bites', 'Kiosk',
#        'Food Truck', 'Quick Bites, Dessert Parlor',
#        'Beverage Shop, Dessert Parlor', 'Takeaway', 'Pub, Casual Dining',
#        'Casual Dining, Bar', 'Dessert Parlor, Beverage Shop',
#        'Quick Bites, Bakery', 'Dessert Parlor, Quick Bites',
#        'Microbrewery, Casual Dining', 'Lounge', 'Bar, Casual Dining',
#        'Food Court', 'Cafe, Bakery', 'Dhaba', 'Quick Bites, Sweet Shop',
#        'Microbrewery', 'Food Court, Quick Bites', 'Pub, Bar',
# ...

# %% [markdown]
# # Q.8)Types of services?

# %%
data.head(2)
# Out:
#              name online_order book_table  rate  votes      location  \
# 0           Jalsa          Yes        Yes   4.1    775  Banashankari
# 1  Spice Elephant          Yes         No   4.1    787  Banashankari
#
#        rest_type                                         dish_liked  \
# 0  Casual Dining  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Casual Dining  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
#
#                          cuisines  cost  \
# 0  North Indian, Mughlai, Chinese   800
# 1     Chinese, North Indian, Thai   800
#
#                                         reviews_list menu_item service  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []  Buffet
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []  Buffet
#
#            city
# 0  Banashankari
# 1  Banashankari

# %%
data['service'].value_counts()
# Out:
# Delivery              25653
# Dine-out              17583
# Desserts               3559
# Cafes                  1703
# Drinks & nightlife     1091
# Buffet                  871
# Pubs and bars           688
# Name: service, dtype: int64

# %%
sns.countplot(x = data['service'])
plt.xticks(rotation = 90)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6]),
#  [Text(0, 0, 'Buffet'),
#   Text(1, 0, 'Cafes'),
#   Text(2, 0, 'Delivery'),
#   Text(3, 0, 'Desserts'),
#   Text(4, 0, 'Dine-out'),
#   Text(5, 0, 'Drinks & nightlife'),
#   Text(6, 0, 'Pubs and bars')])

# %% [markdown]
# # Q.9)Relation between Type and Rating?

# %%
data.head(2)
# Out:
#              name online_order book_table  rate  votes      location  \
# 0           Jalsa          Yes        Yes   4.1    775  Banashankari
# 1  Spice Elephant          Yes         No   4.1    787  Banashankari
#
#        rest_type                                         dish_liked  \
# 0  Casual Dining  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Casual Dining  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
#
#                          cuisines  cost  \
# 0  North Indian, Mughlai, Chinese   800
# 1     Chinese, North Indian, Thai   800
#
#                                         reviews_list menu_item service  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []  Buffet
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []  Buffet
#
#            city
# 0  Banashankari
# 1  Banashankari

# %%
data.rest_type.value_counts()
# Out:
# Quick Bites                   19046
# Casual Dining                 10273
# Cafe                           3687
# Delivery                       2578
# Dessert Parlor                 2245
#                               ...
# Dessert Parlor, Kiosk             2
# Food Court, Beverage Shop         2
# Dessert Parlor, Food Court        2
# Quick Bites, Kiosk                1
# Sweet Shop, Dessert Parlor        1
# Name: rest_type, Length: 93, dtype: int64

# %%
plt.figure(figsize = (15,10))
sns.barplot(data['rest_type'],data['rate'])
plt.xlabel('rest_type')
plt.ylabel('rate')
plt.xticks(rotation = 90)
plt.title('Relation Between rest_type and rate')
plt.show()

# %% [markdown]
# # Q.10)Cost of Restaurant?

# %%
data.head(2)
# Out:
#              name online_order book_table  rate  votes      location  \
# 0           Jalsa          Yes        Yes   4.1    775  Banashankari
# 1  Spice Elephant          Yes         No   4.1    787  Banashankari
#
#        rest_type                                         dish_liked  \
# 0  Casual Dining  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Casual Dining  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
#
#                          cuisines  cost  \
# 0  North Indian, Mughlai, Chinese   800
# 1     Chinese, North Indian, Thai   800
#
#                                         reviews_list menu_item service  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []  Buffet
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []  Buffet
#
#            city
# 0  Banashankari
# 1  Banashankari

# %%
data['cost'].value_counts()
# Out:
# 300     7549
# 400     6517
# 500     4937
# 200     4844
# 600     3691
#         ...
# 60         1
# 5000       1
# 3700       1
# 469        1
# 160        1
# Name: cost, Length: 70, dtype: int64

# %%
plt.figure(figsize = (15,8))
sns.barplot(x = 'rest_type' , y = 'cost',data = data)
plt.title('cost of restaurant')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # Q.11)No. of restaurants in a Location?

# %%
data.head(2)
# Out:
#              name online_order book_table  rate  votes      location  \
# 0           Jalsa          Yes        Yes   4.1    775  Banashankari
# 1  Spice Elephant          Yes         No   4.1    787  Banashankari
#
#        rest_type                                         dish_liked  \
# 0  Casual Dining  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Casual Dining  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
#
#                          cuisines  cost  \
# 0  North Indian, Mughlai, Chinese   800
# 1     Chinese, North Indian, Thai   800
#
#                                         reviews_list menu_item service  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []  Buffet
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []  Buffet
#
#            city
# 0  Banashankari
# 1  Banashankari

# %%
x= data['location'].value_counts().head(10)
x
# Out:
# BTM                      5071
# HSR                      2496
# Koramangala 5th Block    2481
# JP Nagar                 2219
# Whitefield               2109
# Indiranagar              2033
# Jayanagar                1916
# Marathahalli             1808
# Bannerghatta Road        1611
# Bellandur                1271
# Name: location, dtype: int64

# %%
plt.figure(figsize = (8,6))
sns.barplot(x= x.index,y=x)
plt.xticks(rotation = 90)
plt.title('No. of restaurant in location')
plt.show()
